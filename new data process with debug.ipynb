# %%
import pydicom
import numpy as np
import os
import h5py
import os.path

# %%
def save_3_slices_together(dir_path, volume_shape=(440,440,645), output_prefix='stacked file'):
    save_dir = dir_path    
    image_volume = np.zeros(volume_shape)
    i=0
    for filename in os.listdir(dir_path):
        f = os.path.join(dir_path, filename)
        # checking if it is a file
        if os.path.isfile(f):
            img = pydicom.read_file(f)
            img_array = img.pixel_array
            image_volume[:,:,i]=img_array
            i+=1      
    print("The shape of original volume array is {}".format(image_volume.shape))
    
    image_volume[:,:,-1] = image_volume[:,:,-2]
    total_slices = int(image_volume.shape[2] / 3)
    #print(total_slices)
    print("total slice number : {}".format(total_slices))
    for idx in range(1, total_slices-1):
        data = image_volume[:,:,idx-1:idx+2]
        output_filename = output_prefix + str(idx) + ".h5"
        if idx == 1:
            print("The shape of processed volume array is {}".format(data.shape))
        
        with h5py.File(save_dir + "/" + output_filename, 'w') as outFile:
            dataset = outFile.create_dataset('data', data=data)
            dataset.attrs['idx'] = (idx-1, idx, idx+1)
            dataset.attrs['note'] = "Three contiguous slices. Prepared for 2.5-D Pix2Pix"

# %%
print(len([name for name in os.listdir('D:/games') if os.path.isfile(name)]))
# Out:
# 0

# %%
len(os.listdir('D:/games'))
# Out:
# 1413

# %%
rootdir = 'D:/processing data'

i = 1
skipped_folder = []

for root, dirs, files in os.walk(rootdir):
    if len(dirs) == 0: # means we are reaching a dir with no subdir
        if len(os.listdir(root)) == 644:
            save_3_slices_together(dir_path=root)
            print(i)
            print(root)
            print(skipped_folder)
            print('---------------')
            i+=1
        else:
            #save_3_slices_together(dir_path=root)
            skipped_folder += [root]
            print(i)
            print(root)
            print(skipped_folder)
            print('---------------')
            i+=1
# Out:
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 1
# D:/processing data\Subject_109-114\25112021_2_20211125_164659\1-10 dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 2
# D:/processing data\Subject_109-114\25112021_2_20211125_164659\1-100 dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 3
# D:/processing data\Subject_109-114\25112021_2_20211125_164659\1-2 dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 4
# D:/processing data\Subject_109-114\25112021_2_20211125_164659\1-20 dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 5
# D:/processing data\Subject_109-114\25112021_2_20211125_164659\1-4 dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 6
# D:/processing data\Subject_109-114\25112021_2_20211125_164659\1-50 dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 7
# D:/processing data\Subject_109-114\25112021_2_20211125_164659\Full_dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 8
# D:/processing data\Subject_109-114\26112021_1_20211126_164318\1-10 dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 9
# D:/processing data\Subject_109-114\26112021_1_20211126_164318\1-100 dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 10
# D:/processing data\Subject_109-114\26112021_1_20211126_164318\1-2 dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
# 11
# D:/processing data\Subject_109-114\26112021_1_20211126_164318\1-20 dose
# []
# ---------------
# The shape of volume array is (440, 440, 645)
# 215
# The shape of volume array is (440, 440, 3)
#